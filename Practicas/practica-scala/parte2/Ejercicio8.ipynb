// %% [markdown]
// Ejercicio 8 — Creación e inicialización de Arrays

// %%
val values = new Array[Int](4)

values.foreach(println)
println(" ")
values(0) = 19
values(1) = 1
values(2) = 890809089
values(3) = 99

values.foreach(println)
println(s"Longitud del Array: ${values.length}")
// Out:
// 0
// 0
// 0
// 0
//
// 19
// 1
// 890809089
// 99
// Longitud del Array: 4
// values: Array[Int] = Array(19, 1, 890809089, 99)

// %%
¿Qué valores contiene un Array[Int] recién creado antes de que asignes manualmente sus elementos?

Todo 0s
