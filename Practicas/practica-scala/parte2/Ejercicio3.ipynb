// %% [markdown]
// Ejercicio 3 - Tipos numéricos y precisión

// %%
var numeroDecimal1 = 3.14159265358979323846264338327
var numeroDecimal2 = 3.14159265358979323846264338327f
// Out:
// numeroDecimal1: Double = 3.141592653589793
// numeroDecimal2: Float = 3.1415927F

// %%
var valor = 9
var texto = "Marc Pubill"
var booleano = true
// Out:
// valor: Int = 9
// texto: String = "Marc Pubill"
// booleano: Boolean = true

// %% [markdown]
// ### Documentación
//
// Explica:
//
// - Qué diferencia observas entre `Double` y `Float` : Principalmente veo una diferencia sintactica en la cual float siempre tiene que llevar la f detrás como forma de "casting" por así decirlo.
// - Qué tipo utilizarías para representar el número de estudiantes de una clase. : Un int debido a que tiene que ser un número entero.
// - Qué tipo utilizarías para representar si un estudiante ha aprobado. : booleano porque debe ser si o no.
